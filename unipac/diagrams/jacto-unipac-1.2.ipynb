# %%
import warnings 
warnings.filterwarnings('ignore') 
# Importando as bibliotecas necessárias da diagrams
from diagrams import Diagram, Cluster, Edge
from diagrams.gcp.analytics import Bigquery, Dataflow, Composer, DataFusion
from diagrams.gcp.compute import Functions
from diagrams.gcp.ml import AIPlatform, Automl
from diagrams.gcp.storage import Storage
from diagrams.gcp.database import SQL as gcp_sql
from diagrams.custom import Custom 
from diagrams.generic.blank import Blank  
from diagrams.generic.database import SQL
from diagrams.generic.storage import Storage

# https://googlecloudcheatsheet.withgoogle.com/

# %% [markdown]
# #  Overview - 1.2

# %%
title = "Jacto/Unipac - Overview"
filename = "diagrams/jacto-unipac-overview"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")
    
    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")
  
    with Cluster("Platform"):    
        
      # Cluster para agrupar os componentes relacionados ao processamento de dados
        with Cluster("AI/ML"):            
            document_ai = Custom("Document AI", "../assets/google-cloud-icons/document_ai/document_ai.png")

        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold, sensores)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  
            dialogflow = Custom("Dialogflow\n(chatbot)", "../assets/google-cloud-icons/dialogflow/dialogflow.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            mdm = gcp_sql("MDM\n(dados mestre)")
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch, document_ai]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze, mdm]
    
    ## data transformation
    bronze >> [document_ai, dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold, mdm] >> vertex >> automl >> gold
    
    ## ui
    gold >> dialogflow
    gold >> looker

    [vertex, gold, stream] >> datacatalog

    [dialogflow, looker] - users

diag
# Out:
# Warning: node 'bbc442d09620433cac7b07577ad1d7e7', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '73ccac67ab9f490d9fdce38afb11e2cf', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '8d46e3c28a114184b7edffbbd0db4484', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '95660ff2668b4b7d9a3d0a98bf823105', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '8e3da74a5064432492eee3dcb9290f19', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '769d71716a304be8ad8e6860ac0af791', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '9df40cfd7b834142b1d07d07bdb875fc', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node 'd4a7a2747a7641eb851a6ac2f2ccd98b', graph 'Jacto/Unipac - Overview' size too small for label
# Warning: node '745683f51b114013a87c94f626763370', graph 'Jacto/Unipac - Overview' size too small for label

# %% [markdown]
# ## S&OP

# %% [markdown]
# ### Proposta 1 - S&OP Integrado 360° e Previsão de Demanda

# %%
title = "Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda"
filename = "diagrams/jacto-unipac-sop-proposta1-venda"


# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")
    
    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")           
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]

    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold] >> vertex >> automl >> gold
    
    ## ui
    gold >> looker

    [vertex, gold, stream] >> datacatalog

    looker - users

diag
# Out:
# Warning: node '55ec875fedcd445db71fbc00bb733a63', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label
# Warning: node '0a88fc4036184f479047f1e02601f3a8', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label
# Warning: node '004553a73a96427ca901df71eb107df7', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label
# Warning: node '6b3f4f5566af43f8b78b4ff2264148d8', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label
# Warning: node '32c4d76ae2ae4910809676155205dd61', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label
# Warning: node 'dc5b964426d94515b93b9e5c5f891ad4', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label
# Warning: node '0bbbcb107aa04a029029812b9aa609c3', graph 'Jacto/Unipac(S&OP) - S&OP Integrado 360° e Previsão de Demanda' size too small for label

# %% [markdown]
# ### Proposta 2 - S&OP Logística Inteligente e Otimização de Estoque

# %%
title = "Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque"
filename = "diagrams/jacto-unipac-sop-proposta2-logistica"


# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")
    
    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")           
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]

    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold] >> vertex >> automl >> gold
    
    ## ui
    gold >> looker

    [vertex, gold, stream] >> datacatalog

    looker - users

diag
# Out:
# Warning: node 'dcd9f8792fb84db7849e157274a292bc', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label
# Warning: node '3bac9a1167c84eb2b390d1187ef5156b', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label
# Warning: node 'c67b19c848344869b4b0347dac83c0e4', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label
# Warning: node 'd3aaa3adfe73490085040e31b7d48a78', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label
# Warning: node '67b31948c1d045ab8d57bc3de6408f75', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label
# Warning: node '31a003295c08443888f807b7bb3639d8', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label
# Warning: node '505d816db0cd48dc9c40782995d34ccb', graph 'Jacto/Unipac(S&OP) - S&OP Logística Inteligente e Otimização de Estoque' size too small for label

# %% [markdown]
# ### Proposta 3 - Torre de Controle Unipac

# %%
title = "Jacto/Unipac(S&OP) - Torre de Controle Unipac"
filename = "diagrams/jacto-unipac-sop-proposta3-torre"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")
    
    with Cluster("External"):           
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")           

    with Cluster("Platform"):    

        # Cluster para agrupar os componentes relacionados ao processamento de dados
        with Cluster("AI/ML"):            
            document_ai = Custom("Document AI", "../assets/google-cloud-icons/document_ai/document_ai.png")

        with Cluster("Data Ingestion"):            
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        
        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)")        

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  

    composer >> [sync]

    ## data ingestion
    [documents, external_system] >> sync >> bronze

    ## data transformation
    bronze >> [document_ai, dataflow] >> silver
    silver >> dataflow >> gold
    
    
    ## ui
    gold >> looker
    
    [vertex, gold, stream] >> datacatalog

    looker - users

diag
# Out:
# Warning: node 'b3ebf3729890458b84c00f4583c0d487', graph 'Jacto/Unipac(S&OP) - Torre de Controle Unipac' size too small for label
# Warning: node '1c76d1d0a80f41d6b5f15cd580f44a1b', graph 'Jacto/Unipac(S&OP) - Torre de Controle Unipac' size too small for label
# Warning: node 'a5e7822c1fb84812b6779eda9a734c5f', graph 'Jacto/Unipac(S&OP) - Torre de Controle Unipac' size too small for label
# Warning: node '3970905ee2384ba7970467fda4bbd1cf', graph 'Jacto/Unipac(S&OP) - Torre de Controle Unipac' size too small for label
# Warning: node '9870225218764c708bea0acb47cf0c53', graph 'Jacto/Unipac(S&OP) - Torre de Controle Unipac' size too small for label

# %% [markdown]
# ## Centralidade do Cliente

# %% [markdown]
# ### Proposta 4 - Jornada do Cliente 360° e Controle do Nível Econômico

# %%
title = "Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico"
filename = "diagrams/jacto-unipac-centralidade-proposta4-jornada"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")

    
    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")           
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]

    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold] >> vertex >> automl >> gold
    
    ## ui
    gold >> looker

    [vertex, gold, stream] >> datacatalog

    looker - users

diag
# Out:
# Warning: node '52dcb75466da4e9d867b7e2bedd3278c', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label
# Warning: node '460d731f75a649db859784f2a65461cb', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label
# Warning: node '0e8719281d6741a0bb5f4a1b9fc61edb', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label
# Warning: node 'd44f9ebf17fb4165b2d29e8a1f175508', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label
# Warning: node '8eced02f6ee04ad391ab7fcde93cdfd2', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label
# Warning: node 'e5db5b590881414ca737333dde5ece3c', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label
# Warning: node '48dbf65ad00a4aa995eb3fdaa00be84a', graph 'Jacto/Unipac(Centralidade do Cliente) - Jornada do Cliente 360° e Controle do Nível Econômico' size too small for label

# %% [markdown]
# ## Desenvolvimento de Produto

# %% [markdown]
# ### Proposta 5 - P&D Integrado 360° e Otimização de Blendas

# %%
title = "Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas"
filename = "diagrams/jacto-unipac-produto-proposta5-blendas"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")
    
    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_system = SQL("Systems\n(MS Project, outros)")           
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        
        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]


    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold] >> vertex >> automl >> gold
    
    ## ui
    gold >> looker

    [vertex, gold, stream] >> datacatalog

    looker - users

diag
# Out:
# Warning: node '08627cc6c45641078efac5a4870c5af6', graph 'Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas' size too small for label
# Warning: node '257a17880c0c4a81b974a71425f907d7', graph 'Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas' size too small for label
# Warning: node '2135103b3a7f4a1680080152e4f19f8d', graph 'Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas' size too small for label
# Warning: node 'c172717699ee40979002fcf693755920', graph 'Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas' size too small for label
# Warning: node '20de22bcac6f40c49ced1f626708a9b3', graph 'Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas' size too small for label
# Warning: node 'dc07558399784483ab4a764f94a0d304', graph 'Jacto/Unipac(Desenvolvimento de Produto) - P&D Integrado 360° e Otimização de Blendas' size too small for label

# %% [markdown]
# ### Proposta 6 - Automação e Eficiência Operacional em P&D

# %%
title = "Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D"
filename = "diagrams/jacto-unipac-produto-proposta6-automacao"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")

    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_system = SQL("Systems\n(MS Project, outros)")           
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        
        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  
            dialogflow = Custom("Dialogflow\n(chatbot)", "../assets/google-cloud-icons/dialogflow/dialogflow.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]


    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold] >> vertex >> automl >> gold
    
    ## ui
    gold >> looker
    gold >> dialogflow

    [vertex, gold, stream] >> datacatalog

    looker - users
    dialogflow - users


diag
# Out:
# Warning: node '2b731f4146e64629a610fef4406f50b5', graph 'Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D' size too small for label
# Warning: node 'db6171e81010442280bfdaf897210486', graph 'Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D' size too small for label
# Warning: node 'f783b6a53a4243dab91314e92c2b1269', graph 'Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D' size too small for label
# Warning: node '4143eecdc96a4721ae0bfa33ba4b1799', graph 'Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D' size too small for label
# Warning: node '0e01bb9cb9344e73a20bd52a8842a2a4', graph 'Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D' size too small for label
# Warning: node '21c446536eed471b98750654218ea2e9', graph 'Jacto/Unipac(Desenvolvimento de Produto) - Automação e Eficiência Operacional em P&D' size too small for label

# %% [markdown]
# ## Compras

# %% [markdown]
# ### Proposta 7 - Jornada do Fornecedor 360° e Relacionamento Eficiente

# %%
title = "Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente"
filename = "diagrams/jacto-unipac-compras-proposta7-jornada"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")

    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")
    
    with Cluster("Platform"):    
        
      # Cluster para agrupar os componentes relacionados ao processamento de dados
        with Cluster("AI/ML"):            
            document_ai = Custom("Document AI", "../assets/google-cloud-icons/document_ai/document_ai.png")
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")  

        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  
            dialogflow = Custom("Dialogflow\n(chatbot)", "../assets/google-cloud-icons/dialogflow/dialogflow.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
                   

        with Cluster("Data Governance"):
            
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch, document_ai]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]
    documents >> sync >> bronze


    ## data transformation
    bronze >> [document_ai, dataflow] >> silver
    silver >> dataflow >> gold

 # machine learning
    [silver, gold, mdm] >> vertex >> automl >> gold
    
    
    ## ui
    gold >> looker
    gold >> dialogflow

    [vertex, gold, stream] >> datacatalog

    looker - users
    dialogflow - users

diag
# Out:
# Warning: node 'dc5244d2ed644a10b20017012db7ef91', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label
# Warning: node '7d978aae8ab741da97f6cf1629209c14', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label
# Warning: node '3a141bcbe6de42da823b720f4369aa67', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label
# Warning: node '62511c81459941a1953ca2d430f68cdf', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label
# Warning: node '021351c7e97243b8a621dcad1aa02b1e', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label
# Warning: node '57e2aa5e55fe47a6a99bb7eafc0f61a5', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label
# Warning: node 'cbade02280c44da89e747dcb42ebc670', graph 'Jacto/Unipac(Compras) - Jornada do Fornecedor 360° e Relacionamento Eficiente' size too small for label

# %% [markdown]
# ### Proposta 8 - Compras Integrado 360° e Otimização de Contratos de Material Direto

# %%
title = "Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto"
filename = "diagrams/jacto-unipac-compras-proposta8-integracao"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")

    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")         
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")  
                        

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  
            dialogflow = Custom("Dialogflow\n(chatbot)", "../assets/google-cloud-icons/dialogflow/dialogflow.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            

        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze]

    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold] >> vertex >> automl >> gold
    
    ## ui
    gold >> looker
    gold >> dialogflow

    [vertex, gold, stream] >> datacatalog

    looker - users
    dialogflow - users

diag
# Out:
# Warning: node '8c6dda76f7d34ac18ee71594e602d711', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label
# Warning: node '5161c803c10c4c42b93d1b65bbba7420', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label
# Warning: node 'e54bc1bc3d5a44b1bb4ca003faf49114', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label
# Warning: node '6f77b65f40d044ad951d7e41f34f8f4d', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label
# Warning: node '9cd6eab99c304316b50691b51598b33d', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label
# Warning: node '88916dac1bd54769a3d76c4419a5c2e8', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label
# Warning: node '61c9ae12e0d74e9cbbb3eb5f8f62ceac', graph 'Jacto/Unipac(Compras) - Compras Integrado 360° e Otimização de Contratos de Material Direto' size too small for label

# %% [markdown]
# ### Proposta 9 - Materiais Indiretos 360° e Gestão a Vista

# %%
title = "Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista"
filename = "diagrams/jacto-unipac-compras-proposta9-indiretos"

# Criando o diagrama
with Diagram(title, 
             outformat=["png"],
             filename=filename,
             direction="TB",
             show=False) as diag:

    users = Custom("Users", "../assets/group.png")

    with Cluster("External"):           
        external_sap = SQL("SAP")
        external_salesforce = SQL("Sales Force")        
        external_system = SQL("Systems\n(MS Project, outros)")           
        documents = Custom("Documents\n(planilhas,PDFs)", "../assets/document.png")         
    
    with Cluster("Platform"):    
        
        with Cluster("Data Ingestion"):            
            
            # Orquestração com Pub/Sub
            stream = Custom("Pub/Sub\n(stream)", "../assets/google-cloud-icons/pubsub/pubsub.png")
                        
            batch = Dataflow("Dataflow\n(batch)")
            
            # Automação com Cloud Functions
            sync = Functions("Cloud Functions\n(sync)") 

            # Integração de sistemas com Apigee
            api_integration = Custom("Apigee\n(integração API)", "../assets/google-cloud-icons/apigee_api_platform/apigee_api_platform.png")
            
        with Cluster("Data Analytics"):
            
            dataflow = Dataflow("Dataflow\n(transformação)")
            
            # Repositório central BigQuery
            gold = Bigquery("BigQuery\n(gold)")

        with Cluster("Data Orquestration"):                    
            # Orquestração de workflows com Cloud Composer
            composer = Composer("Composer\n(scheduler)")                          

        with Cluster("UI"):    
            
            # Dashboards com Looker
            looker = Custom("Looker\n(dashboards)", "../assets/google-cloud-icons/looker/looker.png")  
            dialogflow = Custom("Dialogflow\n(chatbot)", "../assets/google-cloud-icons/dialogflow/dialogflow.png")  

        with Cluster("Data Lake"): 
            
            bronze = Storage("bronze\n(raw)")   
            silver = Storage("silver\n(trusted - dados limpos)") 
            mdm = gcp_sql("MDM\n(dados mestre)")
            
        with Cluster("AI/ML"):
            
            vertex = Custom("Vertex\n(Machine Learning)", "../assets/google-cloud-icons/vertexai/vertexai.png")              
            automl = Automl("Automl")    

        with Cluster("Data Governance"):
            datacatalog = Custom("Dataplex\n(data catalog)", "../assets/google-cloud-icons/dataplex/dataplex.png")  


    composer >> [sync, batch]

    ## data ingestion
    [external_sap, external_salesforce] >> stream >> bronze 
    [external_system] >> api_integration >> bronze
    [documents, external_system] >> sync >> bronze
    [external_sap, external_system] >> batch >> [bronze, mdm]

    ## data transformation
    bronze >> [dataflow] >> silver
    silver >> dataflow >> gold

    # machine learning
    [silver, gold, mdm] >> vertex >> automl >> gold
    
    ## ui
    gold >> dialogflow
    gold >> looker

    [vertex, gold, stream] >> datacatalog

    looker - users
    dialogflow - users

diag
# Out:
# Warning: node 'ac2864f551f64d6bb54863bcbf1cb307', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '7540d55564734aee9feb5f01ecff6d97', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '2d549f5b2d29497faa59f0ac58dc4549', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '031d78da0b194fd48676cc1b6856fd35', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '167a0fb8a492474aa0efd9aee12efc27', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '129b24a43e3041a1bb068017713bfb69', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '3053d99b7b184b818915d1192ac5d348', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
# Warning: node '7e9c67b01339466481a32605d7636a80', graph 'Jacto/Unipac(Compras) - Materiais Indiretos 360° e Gestão a Vista' size too small for label
